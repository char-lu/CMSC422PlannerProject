# %% [markdown]
# # CMSC722 AI Planning Project -- Domain Independent Planenr
# Hi !
#
# This is a google colab that you can use to work with a domain independent planner if you are struggling to install one on your machine.
#
# This notebook downloads and builds Metric-FF from here: https://fai.cs.uni-saarland.de/hoffmann/metric-ff.html
#
# Running all of the cells in order should result in the "ff" executable being available in the main directory. You can then make system calls to this executable to run experiments from a python script.
#
# Please make a copy of this colab if you want to use it yourself :)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# This installs dependecies for Metric-FF
! sudo apt install flex 
! sudo apt install bison
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libfl-dev libfl2
# Suggested packages:
#   bison flex-doc
# The following NEW packages will be installed:
#   flex libfl-dev libfl2
# 0 upgraded, 3 newly installed, 0 to remove and 24 not upgraded.
# Need to get 334 kB of archives.
# After this operation, 1,127 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 flex amd64 2.6.4-6.2 [317 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libfl2 amd64 2.6.4-6.2 [11.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 libfl-dev amd64 2.6.4-6.2 [6,316 B]
# Fetched 334 kB in 1s (503 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 3.)
# ...

# %%
# This cell gets the Metric-FF source code and extracts it
! curl https://fai.cs.uni-saarland.de/hoffmann/ff/Metric-FF.tgz --output metricff.tar
! tar -xf metricff.tar

# %%
# This cell builds the Metric-FF planner and produces 
# the executable application, ff, which I move into the main directory.
# There will be warnings, but there should not be any errors.
! pwd
# %cd Metric-FF
! make
! mv ff ..
# %cd ..
# Out:
# /content
# /content/Metric-FF
# gcc -c -O6 -Wall -g -ansi    main.c
# In file included from main.c:61:
# ff.h:1990:8: warning: extra tokens at end of #endif directive [-Wendif-labels]
#  1990 | #endif __FF_H
#       |        ^~~~~~
# main.c: In function ‘process_command_line’:
# main.c:999:3: warning: implicit declaration of function ‘memset’ [-Wimplicit-function-declaration]
#   999 |   memset(gcmd_line.ops_file_name, 0, MAX_LENGTH);
#       |   ^~~~~~
# main.c:999:3: warning: incompatible implicit declaration of built-in function ‘memset’
# main.c:77:1: note: include ‘<string.h>’ or provide a declaration of ‘memset’
#    76 | #include "search.h"
#   +++ |+#include <string.h>
#    77 |
# main.c:1004:29: warning: implicit declaration of function ‘strlen’ [-Wimplicit-function-declaration]
#  1004 |     if ( *argv[0] != '-' || strlen(*argv) != 2 ) {
#       |                             ^~~~~~
# main.c:1004:29: warning: incompatible implicit declaration of built-in function ‘strlen’
# ...

# %%
# This is how you run the planner!
! ./ff
# Out:
# usage of ff:
#
# OPTIONS   DESCRIPTIONS
#
# -p <str>    path for operator and fact file
# -o <str>    operator file name
# -f <str>    fact file name
#
# -E          don't do enforced hill-climbing try before bestfirst
#
# -g <num>    set weight w_g in w_g*g(s) + w_h*h(s) [preset: 0]
# -h <num>    set weight w_h in w_g*g(s) + w_h*h(s) [preset: 0]
#
# -O          switch on optimization expression (default is plan length)

# %%
# Run the problem setup to take pddl in first arg and adds (handempty) to the 
# init and writes to second arg
# Ex: python problem_setup.py file1 file2
! python problem_setup.py problems/1/problem1.pddl problem.pddl
# Out:
# drive/MyDrive/blocks-world2/problems/1/problem2.pddl
# drive/MyDrive/blocks-world2/problem.pddl

# %%
! python problem_setup.py problems/1/problem1.pddl problem.pddl
! time ./ff -o domain.pddl -f problem.pddl
# Out:
# drive/MyDrive/blocks-world2/problems/9/problem5.pddl
# drive/MyDrive/blocks-world2/problem.pddl
#
# ff: parsing domain file
# domain 'BLOCKSWORLD' defined
#  ... done.
# ff: parsing problem file
# problem 'BW-19-1-5' defined
#  ... done.
#
#
# no metric specified. plan length assumed.
#
# checking for cyclic := effects --- OK.
#
# ff: search configuration is EHC, if that fails then  best-first on 1*g(s) + 5*h(s) where
#     metric is  plan length
#
# Cueing down from goal distance:   36 into depth [1][2][3]
#                                   35            [1]
#                                   34            [1]
#                                   33            [1]
#                                   32            [1]
#                                   31            [1][2]
#                                   30            [1]
#                                   29            [1][2][3]
#                                   28            [1]
# ...
